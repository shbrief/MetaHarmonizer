# %%
# Change directory to the project root
# %cd /home/lcc/projects/MetaHarmonizer
# Out:
# /home/lcc/projects/MetaHarmonizer
# /home/lcc/miniconda3/envs/demo_env/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# required files:
# data/schema/curated_fields_source_latest_with_flags.csv
# data/schema/ncit_descendants.json
# data/schema/field_value_dict.json

# %%
# Import the SchemaMapEngine class

from src.Engine import get_schema_engine

SchemaMapEngine = get_schema_engine()

# %%
# Choose the clinical data file

file = "data/schema/test.csv"

# %%
# Initialize the SchemaMapEngine

engine = SchemaMapEngine(
    clinical_data_path=file,
    mode="manual",
    top_k=5,
)

# Run the schema mapping
engine.run_schema_mapping()
# Out:
# /home/lcc/miniconda3/envs/demo_env/lib/python3.10/site-packages/torch/nn/modules/module.py:1762: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `BertSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# No sentence-transformers model found with name model_cache/mt-sap-bert. Creating a new one with mean pooling.
#                        original_column matched_stage matched_stage_detail  \
# 0                         2L_TREATMENT        stage1                 dict
# 1                         3L_TREATMENT        stage1                 dict
# 2    ABLATION_EMBOLIZATION_TX_ADJUVANT        stage1                 dict
# 3                    ADC+IMMUNOTHERAPY        stage1                 dict
# 4                          ADC_THERAPY        stage1                 dict
# ..                                 ...           ...                  ...
# 656                     X2YR_TAMOXIFEN        stage1                 dict
# 657                        X2YR_TAXANE        stage1                 dict
# 658                X2YR_VEGF_INHIBITOR        stage1                 dict
# 659                             XRT_TX        stage1                 dict
# 660                    YEAR_OF_SURGERY        stage1                 dict
#
#            match1_field  match1_score                      match1_source  \
# 0        treatment_name           1.0                       2L_TREATMENT
# 1        treatment_name           1.0                       3L_TREATMENT
# 2      treatment_reason           1.0  ABLATION_EMBOLIZATION_TX_ADJUVANT
# 3        treatment_type           1.0                  ADC+IMMUNOTHERAPY
# 4        treatment_type           1.0                        ADC_THERAPY
# ..                  ...           ...                                ...
# 656  treatment_duration           1.0                     X2YR_TAMOXIFEN
# 657  treatment_duration           1.0                        X2YR_TAXANE
# 658  treatment_duration           1.0                X2YR_VEGF_INHIBITOR
# 659      treatment_type           1.0                             XRT_TX
# 660     treatment_start           1.0                    YEAR_OF_SURGERY
#
#          match2_field  match2_score                      match2_source  \
# 0    treatment_reason           1.0                       2L_TREATMENT
# 1    treatment_reason           1.0                       3L_TREATMENT
# 2      treatment_type           1.0  ABLATION_EMBOLIZATION_TX_ADJUVANT
# 3                 NaN           NaN                                NaN
# 4                 NaN           NaN                                NaN
# ..                ...           ...                                ...
# 656    treatment_name           1.0                     X2YR_TAMOXIFEN
# 657    treatment_type           1.0                        X2YR_TAXANE
# 658    treatment_type           1.0                X2YR_VEGF_INHIBITOR
# 659               NaN           NaN                                NaN
# 660    treatment_type           1.0                    YEAR_OF_SURGERY
#
#     match3_field  match3_score match3_source match4_field  match4_score  \
# 0            NaN           NaN           NaN          NaN           NaN
# 1            NaN           NaN           NaN          NaN           NaN
# 2            NaN           NaN           NaN          NaN           NaN
# 3            NaN           NaN           NaN          NaN           NaN
# 4            NaN           NaN           NaN          NaN           NaN
# ..           ...           ...           ...          ...           ...
# 656          NaN           NaN           NaN          NaN           NaN
# 657          NaN           NaN           NaN          NaN           NaN
# 658          NaN           NaN           NaN          NaN           NaN
# 659          NaN           NaN           NaN          NaN           NaN
# 660          NaN           NaN           NaN          NaN           NaN
#
#     match4_source match5_field  match5_score match5_source
# 0             NaN          NaN           NaN           NaN
# 1             NaN          NaN           NaN           NaN
# 2             NaN          NaN           NaN           NaN
# 3             NaN          NaN           NaN           NaN
# 4             NaN          NaN           NaN           NaN
# ..            ...          ...           ...           ...
# 656           NaN          NaN           NaN           NaN
# 657           NaN          NaN           NaN           NaN
# 658           NaN          NaN           NaN           NaN
# 659           NaN          NaN           NaN           NaN
# 660           NaN          NaN           NaN           NaN
#
# [661 rows x 18 columns]

# %%
# Option: evaluation

# Import the schema mapping evaluation module
from evaluation import schema_mapping_evaluation

# Compute evaluation metrics
metrics = schema_mapping_evaluation.compute_accuracy(
    pred_file="data/schema_mapping_eval/test_manual.csv",
    truth_file="data/schema_mapping_eval/truth.csv",
    top_k=5,
    exclude_details=("ncit","alias"),
    save_eval=False,
    out_dir="data/schema_mapping_eval"
)
print(metrics)
# Out:
# {'acc@1': 0.9969742813918305, 'acc@3': 0.9984871406959153, 'acc@5': 0.9984871406959153, 'n_rows': 661.0}
