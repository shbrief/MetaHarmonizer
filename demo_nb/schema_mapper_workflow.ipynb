# %%
# Change directory to the project root
# %cd /home/lcc/projects/MetaHarmonizer
# %cd /Users/cc/Work/MetaHarmonizer
# Out:
# /Users/cc/Work/MetaHarmonizer
# /opt/miniconda3/envs/mh/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# required files:
# data/schema/curated_fields_source_latest_with_flags.csv
# data/schema/ncit_descendants.json
# data/schema/field_value_dict.json

# %%
# Import the SchemaMapEngine class

from src.Engine import get_schema_engine

SchemaMapEngine = get_schema_engine()

# %%
# Choose the clinical data file

file = "data/schema/test.csv"

# %%
# Initialize the SchemaMapEngine

engine = SchemaMapEngine(
    clinical_data_path=file,
    mode="manual",
    top_k=5,
)

# Run the schema mapping
engine.run_schema_mapping()
# Out:
#                                  query   stage    method              match1  \
# 0                         2L_TREATMENT  stage3  ontology      treatment_name
# 1                         3L_TREATMENT  stage3  ontology      treatment_name
# 2    ABLATION_EMBOLIZATION_TX_ADJUVANT  stage2     alias    treatment_reason
# 3                    ADC+IMMUNOTHERAPY  stage2     alias      treatment_type
# 4                          ADC_THERAPY  stage2     alias      treatment_type
# ..                                 ...     ...       ...                 ...
# 656                     X2YR_TAMOXIFEN  stage2     alias  treatment_duration
# 657                        X2YR_TAXANE  stage2     alias  treatment_duration
# 658                X2YR_VEGF_INHIBITOR  stage2     alias  treatment_duration
# 659                             XRT_TX  stage2     alias      treatment_type
# 660                    YEAR_OF_SURGERY  stage2   numeric     treatment_start
#
#      match1_score                      match1_source              match2  \
# 0            1.00                       2L_TREATMENT                 NaN
# 1            1.00                       3L_TREATMENT                 NaN
# 2            1.00  ablation embolization tx adjuvant      treatment_type
# 3            1.00                  adc immunotherapy    treatment_reason
# 4            1.00                        adc therapy    treatment_reason
# ..            ...                                ...                 ...
# 656          1.00                     x2yr tamoxifen      treatment_name
# 657          1.00                        x2yr taxane      treatment_type
# 658          1.00                x2yr vegf inhibitor      treatment_type
# 659          1.00                             xrt tx    treatment_reason
# 660          1.15                    YEAR_OF_SURGERY  treatment_duration
#
#      match2_score                       match2_source            match3  \
# 0             NaN                                 NaN               NaN
# 1             NaN                                 NaN               NaN
# 2          1.0000   ablation embolization tx adjuvant  treatment_status
# 3          0.8073              adjuvant immunotherapy  treatment_status
# 4          0.6231                    adjuvant therapy    treatment_name
# ..            ...                                 ...               ...
# 656        1.0000                      x2yr tamoxifen    treatment_type
# 657        1.0000                         x2yr taxane    treatment_name
# 658        1.0000                 x2yr vegf inhibitor    treatment_name
# 659        0.6364                             adj xrt  treatment_status
# 660        0.8605  SURGERY_DATE_RELATIVE_TO_DX_MONTHS  treatment_number
#
#      match3_score              match3_source              match4  \
# 0             NaN                        NaN                 NaN
# 1             NaN                        NaN                 NaN
# 2          0.4825           postoperative tx      treatment_name
# 3          0.6660  post sample immunotherapy                 NaN
# 4          0.5359             adjuvant chemo                 NaN
# ..            ...                        ...                 ...
# 656        0.6088                x2yr taxane                 NaN
# 657        0.7129              x2yr antiher2                 NaN
# 658        0.5588             x2yr tamoxifen                 NaN
# 659        0.6101            post sample xrt                 NaN
# 660        0.6323             SURGERY NUMBER  age_at_procurement
#
#      match4_score               match4_source match5  match5_score  \
# 0             NaN                         NaN    NaN           NaN
# 1             NaN                         NaN    NaN           NaN
# 2          0.4280  pharm tx mitotane adjuvant    NaN           NaN
# 3             NaN                         NaN    NaN           NaN
# 4             NaN                         NaN    NaN           NaN
# ..            ...                         ...    ...           ...
# 656           NaN                         NaN    NaN           NaN
# 657           NaN                         NaN    NaN           NaN
# 658           NaN                         NaN    NaN           NaN
# 659           NaN                         NaN    NaN           NaN
# 660        0.5457            AGE_AT_RESECTION    NaN           NaN
#
#     match5_source
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ..            ...
# 656           NaN
# 657           NaN
# 658           NaN
# 659           NaN
# 660           NaN
#
# [661 rows x 18 columns]

# %%
# Option: evaluation

# Import the schema mapping evaluation module
from evaluation import schema_mapping_evaluation

# Compute evaluation metrics
metrics = schema_mapping_evaluation.compute_accuracy(
    pred_file="data/schema_mapping_eval/test_manual.csv",
    truth_file="data/schema_mapping_eval/truth.csv",
    top_k=5,
    #exclude_methods=("alias",),
    save_eval=True,
    out_dir="data/schema_mapping_eval"
)
print(metrics)
# Out:
# {'acc@1': 0.8065693430656934, 'acc@3': 0.8540145985401459, 'acc@5': 0.8540145985401459, 'n_rows': 274.0}
